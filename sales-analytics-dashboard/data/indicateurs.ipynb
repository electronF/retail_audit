# %%
import pandas as pd

# %%
indicateur=pd.read_csv("./Indicateurs & Formules(Feuil1).csv", sep=";")
indicateur
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0                        Indicateurs liés aux volumes         NaN
# 1                                    MARKET%SHARE VOL         NaN
# 2                                VOLUME EN HECTOLITRE         NaN
# 3                            SHARE IN SHOP HANDLING %         NaN
# 4                                    MARKET%SHARE VAL         NaN
# 5                           VALEUR EN UNITÉ MONETAIRE         NaN
# 6                                PURCHASES%SHARES VOL         NaN
# 7                                         STOCK%SHARE         NaN
# 8                                  FOWARD STOCK%SHARE         NaN
# 9                                                Prix         NaN
# 10                                      AVERAGE PRICE         NaN
# 11                 Indicateurs liés à la distribution         NaN
# 12                              NUMERIC DISTRIBUTION%         NaN
# ...
